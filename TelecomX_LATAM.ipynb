# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 5206  7108-DGVUU    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 3273  4566-GOLUK   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6957  9578-VRMNM   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 725   1038-ZAGBI   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4420  6050-FFXES    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 5206  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 3273  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6957  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 725    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4420  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 5206  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 3273  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
print(df.isnull().sum())
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 5159  7036-ZZKBD    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4987  6821-JPCDC    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3958  5404-GGUKR    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3129  4361-FEBGN    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3062  4274-DRSQT    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 5159   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4987   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3958   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3129   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3062  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 5159  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 4987  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df["Churn"] = df["Churn"].fillna(0).astype(int)

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 5403  7394-FKDNK      1  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5743  7851-WZEKY      1  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3705  5117-IFGPS      0  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 5167  7054-DMVAS      0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2219  3096-JRDSO      1  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                                 phone  \
# 5403   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5743  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 3705  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5167   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2219  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 5403  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5743  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ##Cliente

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 5691  Female              0     Yes        Yes      12
# 2258    Male              0     Yes         No      60
# 5417    Male              0      No         No      25
# 2830  Female              0      No         No      41
# 4836  Female              0      No         No      18

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 323     Male              0        0           0      29
# 3791  Female              0        1           1      12
# 987   Female              0        1           1      20
# 6746  Female              0        1           1      57
# 6721    Male              0        1           0      65

# %% [markdown]
# ##Telefono

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService     MultipleLines
# 1986           No  No phone service
# 4370          Yes                No
# 2254          Yes               Yes
# 4608          Yes                No
# 6502          Yes                No

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 94               1              1
# 6985             1              0
# 155              1              1
# 5426             1              1
# 6879             1              1

# %% [markdown]
# ##Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
internet.sample(5)
# Out:
#      InternetService       OnlineSecurity         OnlineBackup  \
# 1594              No  No internet service  No internet service
# 5868     Fiber optic                   No                   No
# 720      Fiber optic                   No                   No
# 2947     Fiber optic                   No                   No
# 6154     Fiber optic                   No                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1594  No internet service  No internet service  No internet service
# 5868                   No                  Yes                   No
# 720                    No                   No                   No
# 2947                   No                   No                   No
# 6154                   No                   No                   No
#
#           StreamingMovies
# 1594  No internet service
# 5868                   No
# 720                    No
# 2947                   No
# 6154                  Yes

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
int_trans = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
internet[int_trans] = internet[int_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No internet service': 0}))

# %%
internet.sample(5)
# Out:
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3921             DSL               1             1                 1
# 1303     Fiber optic               0             0                 1
# 2410     Fiber optic               0             0                 0
# 5351             DSL               1             1                 1
# 4125             DSL               0             1                 0
#
#       TechSupport  StreamingTV  StreamingMovies
# 3921            1            1                1
# 1303            1            1                1
# 2410            0            1                0
# 5351            0            0                0
# 4125            0            0                0

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   int64
#  2   OnlineBackup      7267 non-null   int64
#  3   DeviceProtection  7267 non-null   int64
#  4   TechSupport       7267 non-null   int64
#  5   StreamingTV       7267 non-null   int64
#  6   StreamingMovies   7267 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 397.5+ KB

# %% [markdown]
# ##Cuenta

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
cuenta.sample(5)
# Out:
#             Contract PaperlessBilling            PaymentMethod  \
# 3256  Month-to-month              Yes  Credit card (automatic)
# 2802        One year              Yes         Electronic check
# 5652        One year              Yes  Credit card (automatic)
# 5307  Month-to-month               No         Electronic check
# 1692  Month-to-month              Yes         Electronic check
#
#       Charges.Monthly Charges.Total
# 3256            74.75       1129.35
# 2802           109.25        8109.8
# 5652           106.40        7251.9
# 5307            54.50          54.5
# 1692            70.15        916.75

# %%
#Cambiar titulo de columna, reemplazando "." por "_"
cuenta.rename(columns=lambda x: x.replace('.', '_'), inplace=True)

# %%
cuenta['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
#cuenta["Charges_Total"].astype(float)
cuenta["Charges_Total"] = pd.to_numeric(cuenta["Charges_Total"], errors='coerce')

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges_Monthly   7267 non-null   float64
#  4   Charges_Total     7256 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 284.0+ KB

# %%
# Transformar la columna 'InternetService' en el DataFrame internet
internet = pd.get_dummies(internet, columns=['InternetService'], prefix='InternetService', drop_first=True)

# Transformar las columnas categóricas en el DataFrame cuenta
cuenta = pd.get_dummies(cuenta, columns=['Contract', 'PaperlessBilling', 'PaymentMethod'], prefix='', drop_first=True)

print("DataFrame internet después de la transformación:")
internet.head()
print("\nDataFrame cuenta después de la transformación:")
cuenta.head()
# Out:
# DataFrame internet después de la transformación:
#
# DataFrame cuenta después de la transformación:
#    Charges_Monthly  Charges_Total  _One year  _Two year   _Yes  \
# 0             65.6         593.30       True      False   True
# 1             59.9         542.40      False      False  False
# 2             73.9         280.85      False      False   True
# 3             98.0        1237.85      False      False   True
# 4             83.9         267.40      False      False   True
#
#    _Credit card (automatic)  _Electronic check  _Mailed check
# 0                     False              False           True
# 1                     False              False           True
# 2                     False               True          False
# 3                     False               True          False
# 4                     False              False           True

# %%
# Fusionar los DataFrames ya que normalizamos sin customerID, concatenaremos por índice.

df_merged = pd.concat([df[['customerID', 'Churn']], cliente, telefono, internet, cuenta], axis=1)

print("\nDataFrame fusionado:")
df_merged.head()
print("\nInformación del DataFrame fusionado:")
df_merged.info()
# Out:
# DataFrame fusionado:
#
# Información del DataFrame fusionado:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customerID                   7267 non-null   object
#  1   Churn                        7267 non-null   int64
#  2   gender                       7267 non-null   object
#  3   SeniorCitizen                7267 non-null   int64
#  4   Partner                      7267 non-null   int64
#  5   Dependents                   7267 non-null   int64
#  6   tenure                       7267 non-null   int64
#  7   PhoneService                 7267 non-null   int64
#  8   MultipleLines                7267 non-null   int64
#  9   OnlineSecurity               7267 non-null   int64
#  10  OnlineBackup                 7267 non-null   int64
#  11  DeviceProtection             7267 non-null   int64
# ...

# %%
df_merged['Cuentas_Diarias'] = df_merged['Charges_Monthly'] / 30

print("\nDataFrame fusionado con la nueva columna 'Cuentas_Diarias':")
df_merged.head()
# Out:
# DataFrame fusionado con la nueva columna 'Cuentas_Diarias':
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines  OnlineSecurity  ...  InternetService_No  \
# 0             1              0               0  ...               False
# 1             1              1               0  ...               False
# 2             1              0               0  ...               False
# 3             1              0               0  ...               False
# 4             1              0               0  ...               False
#
# ...

# %% [markdown]
# ## Análisis descriptivo
#
# Analizar los datos de clientes de Telecom X para identificar patrones y tendencias de evasión (churn) siguiendo los pasos proporcionados, incluyendo análisis descriptivo, distribución de churn por variables categóricas y numéricas.

# %%
cols_numericas = df_merged.select_dtypes(include=np.number)
stats_descriptivos = cols_numericas.describe()
print(stats_descriptivos)
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7267.000000    7267.000000  7267.000000  7267.000000  7267.000000
# mean      0.257190       0.162653     0.484106     0.300124    32.346498
# std       0.437115       0.369074     0.499782     0.458343    24.571773
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  OnlineSecurity  OnlineBackup  \
# count   7267.000000    7267.000000     7267.000000   7267.000000
# mean       0.902711       0.421770        0.285950      0.344571
# std        0.296371       0.493876        0.451897      0.475261
# ...

# %% [markdown]
# ## Visualización de la distribución de churn

# %%
conteo_chrun = df_merged['Churn'].value_counts()

plt.figure(figsize=(6, 4))
sns.barplot(x=conteo_chrun.index, y=conteo_chrun.values)
plt.title('Proporción de Churned vs Clientes Non-Churned')
plt.xlabel('Churn (0: No Churn, 1: Churn)')
plt.ylabel('numero de clientes')
plt.xticks([0, 1], ['No Churn', 'Churn'])
plt.show()

# %% [markdown]
# ## Recuento de churn por variables categóricas

# %%
categorical_cols = df_merged.select_dtypes(include='object').columns.tolist()
categorical_cols.remove('customerID')
if 'gender' in categorical_cols:
    categorical_cols.remove('gender')

for col in categorical_cols:
    plt.figure(figsize=(8, 5))
    churn_by_category = df_merged.groupby(col)['Churn'].value_counts(normalize=True).unstack().fillna(0)
    churn_by_category.plot(kind='bar', stacked=True, figsize=(8, 5))
    plt.title(f'Churn Distribution by {col}')
    plt.xlabel(col)
    plt.ylabel('Proportion of Customers')
    plt.xticks(rotation=0)
    plt.legend(title='Churn', labels=['No', 'Yes'])
    plt.show()

# %% [markdown]
# ## Análisis de churn por variables numéricas

# %%
numerical_cols_for_churn = df_merged.select_dtypes(include=np.number).columns.tolist()
if 'Churn' in numerical_cols_for_churn:
    numerical_cols_for_churn.remove('Churn')

for col in numerical_cols_for_churn:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x='Churn', y=col, data=df_merged)
    plt.title(f'Distribución de {col} por Churn')
    plt.xlabel('Churn (0: No Churn, 1: Churn)')
    plt.ylabel(col)
    plt.xticks([0, 1], ['No Churn', 'Churn'])
    plt.show()

# %% [markdown]
# # 📄 Informe Final
#
# ## Introducción
#
# El presente informe tiene como objetivo analizar los datos de clientes de Telecom X para identificar patrones y tendencias relacionadas con la evasión de clientes (Churn). El Churn es un desafío significativo para las empresas de telecomunicaciones, ya que la adquisición de nuevos clientes suele ser más costosa que la retención de los existentes. Comprender los factores que influyen en la decisión de un cliente de irse es crucial para desarrollar estrategias efectivas de retención.
#
# ## Limpieza y Tratamiento de Datos
#
# Se importaron los datos directamente desde la API de Telecom X en formato JSON y se convirtieron a un DataFrame de Pandas. Durante la fase de limpieza y tratamiento, se realizaron los siguientes pasos:
#
# *   Se verificó la presencia de valores nulos y se identificaron valores faltantes en la columna `Charges_Total`.
# *   Se normalizaron las columnas anidadas (`customer`, `phone`, `internet`, `account`) en DataFrames separados.
# *   Se transformaron las variables categóricas binarias ('Yes'/'No', 'Male'/'Female') a valores numéricos (1/0).
# *   Se manejaron los valores 'No phone service' y 'No internet service' en las columnas correspondientes, asignándoles el valor 0.
# *   Se renombró la columna `Charges.Total` a `Charges_Total` para mayor consistencia.
# *   Se convirtió la columna `Charges_Total` a tipo numérico, coercing errors para manejar posibles inconsistencias.
# *   Se crearon variables dummy para las columnas categóricas restantes (`InternetService`, `Contract`, `PaperlessBilling`, `PaymentMethod`).
# *   Se concatenaron todos los DataFrames resultantes en un único DataFrame fusionado (`df_merged`).
# *   Se calculó la columna `Cuentas_Diarias` dividiendo `Charges_Monthly` por 30.
#
# ## Análisis Exploratorio de Datos (EDA)
#
# Se realizó un análisis exploratorio de datos para comprender la distribución de las variables y su relación con el Churn. Los hallazgos clave incluyen:
#
# *   **Estadísticas Descriptivas:** Se calcularon estadísticas descriptivas para las columnas numéricas, revelando la distribución de variables como `tenure`, `Charges_Monthly` y `Charges_Total`, así como la presencia de valores nulos en `Charges_Total`.
# *   **Distribución de Churn:** Se visualizó la proporción de clientes con y sin churn, mostrando un desbalance en el conjunto de datos con una mayor cantidad de clientes que no han evadido.

# %%
churn_counts = df_merged['Churn'].value_counts()

plt.figure(figsize=(6, 4))
sns.barplot(x=churn_counts.index, y=churn_counts.values)
plt.title('Proporción de Clientes con y sin Churn')
plt.xlabel('Churn (0: No Churn, 1: Churn)')
plt.ylabel('Número de Clientes')
plt.xticks([0, 1], ['No Churn', 'Churn'])
plt.show()

# %% [markdown]
# *   **Recuento de Churn por Variables Categóricas:** Se analizaron las tasas de churn para diferentes categorías. Se observaron diferencias notables en la tasa de churn para variables como:
#     *   **Tipo de Contrato:** Clientes con contratos mes a mes (`Month-to-month`) tienen una tasa de churn significativamente más alta que aquellos con contratos de uno o dos años.
#     *   **Servicio de Internet:** Los clientes con servicio de fibra óptica (`Fiber optic`) presentan una tasa de churn mayor en comparación con los que tienen DSL o no tienen servicio de internet.
#     *   **Método de Pago:** El pago electrónico (`Electronic check`) parece estar asociado con una mayor tasa de churn.

# %%
categorical_cols = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                    'StreamingTV', 'StreamingMovies', 'InternetService_Fiber optic',
                    'InternetService_No', '_One year', '_Two year', '_Yes',
                    '_Credit card (automatic)', '_Electronic check', '_Mailed check']

for col in categorical_cols:
    plt.figure(figsize=(8, 5))
    churn_by_category = df_merged.groupby(col)['Churn'].value_counts(normalize=True).unstack().fillna(0)
    churn_by_category.plot(kind='bar', stacked=True, figsize=(8, 5))
    plt.title(f'Distribución de Churn por {col}')
    plt.xlabel(col)
    plt.ylabel('Proporción de Clientes')
    plt.xticks(rotation=0)
    plt.legend(title='Churn', labels=['No', 'Yes'])
    plt.show()

# %% [markdown]
# *   **Análisis de Churn por Variables Numéricas:** Se exploró la distribución de variables numéricas en relación con el churn. Los box plots mostraron que:
#     *   Los clientes que evaden (`Churn = 1`) tienden a tener una menor **antigüedad** (`tenure`) en la empresa.
#     *   Los clientes que evaden (`Churn = 1`) tienden a tener **cargos mensuales** (`Charges_Monthly`) más altos.
#     *   Los **cargos totales** (`Charges_Total`) son generalmente menores para los clientes que evaden, lo cual es coherente con su menor antigüedad.

# %%
numerical_cols_for_churn = ['tenure', 'Charges_Monthly', 'Charges_Total', 'Cuentas_Diarias']

for col in numerical_cols_for_churn:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x='Churn', y=col, data=df_merged)
    plt.title(f'Distribución de {col} por Churn')
    plt.xlabel('Churn (0: No Churn, 1: Churn)')
    plt.ylabel(col)
    plt.xticks([0, 1], ['No Churn', 'Churn'])
    plt.show()

# %% [markdown]
# ## Conclusiones e Insights
#
# Los principales hallazgos de este análisis sugieren que el Churn en Telecom X está influenciado por una combinación de factores demográficos, de servicio y de cuenta. Los clientes con contratos a corto plazo (mes a mes), aquellos que utilizan el servicio de fibra óptica y los que pagan electrónicamente tienen una mayor probabilidad de evadir. Además, los clientes con menor antigüedad y mayores cargos mensuales también muestran una mayor tendencia al churn.
#
# Estos insights pueden ayudar a Telecom X a identificar a los clientes en riesgo de evasión y a desarrollar estrategias de retención dirigidas.
#
# ## Recomendaciones
#
# Basado en el análisis, se sugieren las siguientes recomendaciones estratégicas para reducir la evasión de clientes:
#
# *   **Programas de Retención para Clientes con Contratos Mes a Mes:** Ofrecer incentivos para que los clientes cambien a contratos de mayor duración.
# *   **Mejorar la Calidad del Servicio de Fibra Óptica:** Investigar las razones detrás de la alta tasa de churn entre los usuarios de fibra óptica y tomar medidas para mejorar la calidad del servicio o la atención al cliente.
# *   **Optimizar los Métodos de Pago Electrónico:** Analizar si hay problemas o fricciones en el proceso de pago electrónico que puedan estar contribuyendo al churn y buscar soluciones.
# *   **Programas de Lealtad y Beneficios por Antigüedad:** Recompensar a los clientes con mayor antigüedad para fomentar la lealtad.
# *   **Análisis más Profundo de Clientes con Altos Cargos Mensuales:** Identificar si los clientes con altos cargos mensuales perciben un valor acorde al costo y abordar posibles preocupaciones.
# *   **Implementación de Modelos Predictivos de Churn:** Utilizar los insights obtenidos para desarrollar modelos de machine learning que predigan qué clientes tienen un alto riesgo de evadir, permitiendo intervenciones proactivas.
#
# Este analisis está hecho para comprender el chrun en Telecom X, continuaremos nuestroi analisis en la segunda parte del chalenge, donde analizaremos seguramente de mejor manera la correlacion entre diferentes variables, con la finalidad de resolver estrategias para retener clientes nuevos y actuales.
