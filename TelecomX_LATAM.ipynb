# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 5489  7521-YXVZY    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7054  9715-SBVSU    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 592   0842-IWYCP    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1653  2347-WKKAE    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5475  7503-ZGUZJ    1.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 5489   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7054   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 592    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1653  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5475  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 5489  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7054  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 592   {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1653  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5475  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account
# 5489  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7054  {'Contract': 'Two year', 'PaperlessBilling': '...
# 592   {'Contract': 'Month-to-month', 'PaperlessBilli...
# 1653  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5475  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df["Churn"] = df["Churn"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   Churn       7043 non-null   int64
#  2   customer    7043 non-null   object
#  3   phone       7043 non-null   object
#  4   internet    7043 non-null   object
#  5   account     7043 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 385.2+ KB

# %%
print(df.isnull().sum())
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 6300  8663-UPDGF      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 602   0859-YGKFW      0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2782  3858-XHYJO      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3380  4693-VWVBO      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3263  4550-VBOFE      1  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
#
#                                                 phone  \
# 6300  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 602    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2782  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 3380   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3263  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 6300  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 602   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 2782  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3380  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 3263  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account
# 6300  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 602   {'Contract': 'One year', 'PaperlessBilling': '...
# 2782  {'Contract': 'One year', 'PaperlessBilling': '...
# 3380  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3263  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# ##Cliente

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 2021    Male              0      No        Yes      34
# 2908  Female              0      No         No       2
# 1501    Male              0     Yes         No      13
# 5792    Male              1      No         No      51
# 3693  Female              0     Yes         No      59

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 3402  Female              0        1           1      20
# 1589    Male              0        0           0       7
# 659   Female              0        0           1      13
# 1782  Female              0        1           0      71
# 5921  Female              0        1           0      62

# %% [markdown]
# ##Telefono

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService     MultipleLines
# 6560           No  No phone service
# 6352          Yes               Yes
# 6795          Yes                No
# 2438          Yes               Yes
# 1820           No  No phone service

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 5914             1              0
# 2217             1              1
# 7110             1              0
# 927              1              0
# 635              1              0

# %% [markdown]
# ##Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
internet.sample(5)
# Out:
#      InternetService       OnlineSecurity         OnlineBackup  \
# 2701     Fiber optic                   No                  Yes
# 6843              No  No internet service  No internet service
# 4764     Fiber optic                   No                   No
# 3620     Fiber optic                   No                  Yes
# 1221              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 2701                   No                   No                   No
# 6843  No internet service  No internet service  No internet service
# 4764                   No                   No                  Yes
# 3620                  Yes                   No                   No
# 1221  No internet service  No internet service  No internet service
#
#           StreamingMovies
# 2701                   No
# 6843  No internet service
# 4764                  Yes
# 3620                  Yes
# 1221  No internet service

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
int_trans = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
internet[int_trans] = internet[int_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No internet service': 0}))

# %%
internet.sample(5)
# Out:
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3671              0.0             NaN           NaN               NaN
# 1893              NaN             NaN           NaN               NaN
# 5071              NaN             NaN           NaN               NaN
# 2900              0.0             NaN           NaN               NaN
# 6329              NaN             NaN           NaN               NaN
#
#       TechSupport  StreamingTV  StreamingMovies
# 3671          NaN          NaN              NaN
# 1893          NaN          NaN              NaN
# 5071          NaN          NaN              NaN
# 2900          NaN          NaN              NaN
# 6329          NaN          NaN              NaN

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
