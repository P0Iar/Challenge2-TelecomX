# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 7232  9944-HKVVB   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5343  7296-PIXQY    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2596  3623-FQBOX    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4980  6814-ZPWFQ    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 1069  1498-DQNRX    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 7232   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5343   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2596   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4980  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1069   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 7232  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5343  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2596  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4980  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1069  {'InternetService': 'No', 'OnlineSecurity': 'N...
#
#                                                 account
# 7232  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5343  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2596  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4980  {'Contract': 'One year', 'PaperlessBilling': '...
# 1069  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
print(df.isnull().sum())
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 1693  2400-FEQME    NaN  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1371  1981-INRFU    NaN  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2893  4011-ARPHK    NaN  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6561  9026-RNUJS    NaN  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4780  6549-NNDYT    NaN  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# 1693     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1371     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2893     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6561     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4780  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 1693  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1371  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2893  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6561  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 4780  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 1693  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1371  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2893  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 6561  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4780  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# ##Cliente

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 3838  Female              1     Yes        Yes      72
# 4496    Male              0     Yes         No      72
# 3488  Female              0     Yes        Yes      32
# 3051  Female              1     Yes         No      17
# 6579  Female              1     Yes         No      65

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 2149  Female              0        0           1       2
# 2284    Male              0        0           0      66
# 754     Male              1        1           0      64
# 6892    Male              0        0           0      69
# 4080    Male              0        1           0       1

# %% [markdown]
# ##Telefono

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService     MultipleLines
# 1216          Yes               Yes
# 6033          Yes                No
# 6491           No  No phone service
# 2276          Yes                No
# 5829          Yes               Yes

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 6588             1              0
# 5272             1              0
# 3851             0              0
# 5038             1              1
# 6899             1              0

# %% [markdown]
# ##Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
internet.sample(5)
# Out:
#      InternetService       OnlineSecurity         OnlineBackup  \
# 3890             DSL                  Yes                   No
# 6788              No  No internet service  No internet service
# 6315     Fiber optic                   No                   No
# 6010             DSL                  Yes                  Yes
# 5924     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3890                  Yes                  Yes                  Yes
# 6788  No internet service  No internet service  No internet service
# 6315                   No                  Yes                   No
# 6010                  Yes                  Yes                  Yes
# 5924                  Yes                   No                  Yes
#
#           StreamingMovies
# 3890                   No
# 6788  No internet service
# 6315                   No
# 6010                   No
# 5924                  Yes

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
