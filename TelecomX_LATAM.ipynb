# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 3900  5332-UJJBL        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1918  2716-GFZOR    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2428  3393-FMZPV   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 995   1397-XKKWR    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3012  4187-CINZD   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                                   phone  \
# 3900     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1918     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2428    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 995   {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 3012     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 3900  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1918  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2428  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 995   {'InternetService': 'DSL', 'OnlineSecurity': '...
# 3012  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account
# 3900  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 1918  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2428  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 995   {'Contract': 'One year', 'PaperlessBilling': '...
# 3012  {'Contract': 'One year', 'PaperlessBilling': '...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
print(df.isnull().sum())
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 5097  6968-GMKPR    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5574  7621-VPNET    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1174  1678-FYZOW    1.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3681  5073-RZGBK    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2957  4106-HADHQ    1.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 5097   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5574  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1174   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3681  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2957   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 5097  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5574  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1174  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3681  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2957  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 5097  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5574  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 1174  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3681  {'Contract': 'One year', 'PaperlessBilling': '...
# 2957  {'Contract': 'One year', 'PaperlessBilling': '...

# %%
df["Churn"] = df["Churn"].astype(int)

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 62    0106-GHRQR      0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4103  5624-RYAMH      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3261  4549-ZDQYY      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 504   0716-BQNDX      0  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 511   0725-CXOTM      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 62    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4103   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3261   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 504   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 511   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 62    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 4103  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 3261  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 504   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 511   {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 62    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4103  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3261  {'Contract': 'One year', 'PaperlessBilling': '...
# 504   {'Contract': 'Two year', 'PaperlessBilling': '...
# 511   {'Contract': 'One year', 'PaperlessBilling': '...

# %% [markdown]
# ##Cliente

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 2470    Male              0      No         No      46
# 1618  Female              0     Yes         No      65
# 2720  Female              0     Yes        Yes      68
# 280     Male              0      No         No       3
# 3552    Male              0     Yes        Yes      35

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 900   Female              0        1           0      64
# 1841  Female              0        0           0       1
# 1015    Male              0        0           0      11
# 5471  Female              0        1           0      46
# 161   Female              1        1           0      27

# %% [markdown]
# ##Telefono

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService MultipleLines
# 2482          Yes            No
# 601           Yes            No
# 2066          Yes           Yes
# 6716          Yes           Yes
# 6742          Yes           Yes

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 7256             1              0
# 2346             1              1
# 4535             1              1
# 247              1              0
# 3012             1              0

# %% [markdown]
# ##Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
internet.sample(5)
# Out:
#      InternetService       OnlineSecurity         OnlineBackup  \
# 479      Fiber optic                   No                   No
# 1284             DSL                   No                  Yes
# 2579              No  No internet service  No internet service
# 4212              No  No internet service  No internet service
# 1377              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 479                    No                   No                   No
# 1284                   No                   No                   No
# 2579  No internet service  No internet service  No internet service
# 4212  No internet service  No internet service  No internet service
# 1377  No internet service  No internet service  No internet service
#
#           StreamingMovies
# 479                    No
# 1284                   No
# 2579  No internet service
# 4212  No internet service
# 1377  No internet service

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
int_trans = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
internet[int_trans] = internet[int_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No internet service': 0}))

# %%
internet.sample(5)
# Out:
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3278              No               0             0                 0
# 7047             DSL               0             0                 1
# 2986             DSL               1             0                 0
# 4163             DSL               0             0                 0
# 2713     Fiber optic               1             0                 0
#
#       TechSupport  StreamingTV  StreamingMovies
# 3278            0            0                0
# 7047            1            1                0
# 2986            1            0                1
# 4163            1            0                0
# 2713            0            1                1

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   int64
#  2   OnlineBackup      7267 non-null   int64
#  3   DeviceProtection  7267 non-null   int64
#  4   TechSupport       7267 non-null   int64
#  5   StreamingTV       7267 non-null   int64
#  6   StreamingMovies   7267 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 397.5+ KB

# %% [markdown]
# ##Cuenta

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
cuenta.sample(5)
# Out:
#             Contract PaperlessBilling              PaymentMethod  \
# 3732  Month-to-month               No  Bank transfer (automatic)
# 2992  Month-to-month              Yes           Electronic check
# 4203  Month-to-month               No               Mailed check
# 6836  Month-to-month              Yes               Mailed check
# 5679        One year               No               Mailed check
#
#       Charges.Monthly Charges.Total
# 3732            93.00        870.25
# 2992            81.30         416.3
# 4203            20.45        150.75
# 6836            87.10        341.45
# 5679            19.70         94.45

# %%
#Cambiar titulo de columna, reemplazando "." por "_"
cuenta.rename(columns=lambda x: x.replace('.', '_'), inplace=True)

# %%
cuenta['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
#cuenta["Charges_Total"].astype(float)
cuenta["Charges_Total"] = pd.to_numeric(cuenta["Charges_Total"], errors='coerce')

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges_Monthly   7267 non-null   float64
#  4   Charges_Total     7256 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 284.0+ KB

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
