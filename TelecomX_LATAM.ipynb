# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 6825  9411-TPQQV    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2845  3948-FVVRP    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6038  8242-JSVBO    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 981   1379-FRVEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1620  2302-ANTDP   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                                   phone  \
# 6825  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 2845     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6038     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 981     {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1620    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 6825  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2845  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6038  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 981   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1620  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account
# 6825  {'Contract': 'One year', 'PaperlessBilling': '...
# 2845  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 6038  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 981   {'Contract': 'Month-to-month', 'PaperlessBilli...
# 1620  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 5783    Male              1     Yes         No       1
# 3164    Male              0     Yes        Yes      13
# 6965    Male              1      No         No      55
# 4511  Female              1      No         No      43
# 1398    Male              0     Yes         No      63

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#      gender  SeniorCitizen  Partner  Dependents  tenure
# 2735   Male              0        0           0       1
# 2787   Male              0        1           1      72
# 5147   Male              0        0           0      41
# 1281   Male              0        1           1      50
# 875    Male              0        0           0      58

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService     MultipleLines
# 1216          Yes               Yes
# 6033          Yes                No
# 6491           No  No phone service
# 2276          Yes                No
# 5829          Yes               Yes

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 6588             1              0
# 5272             1              0
# 3851             0              0
# 5038             1              1
# 6899             1              0

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
