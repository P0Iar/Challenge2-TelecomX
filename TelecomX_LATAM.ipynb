# %% [markdown]
# <a href="https://colab.research.google.com/github/P0Iar/Challenge2-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_json('https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json')

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df= df.dropna(subset=['Churn'])

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 6725  9258-CNWAC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1758  2499-AJYUA    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 6463  8882-TLVRW    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 949   1336-EZFZY    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7257  9975-SKRNR    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 6725    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1758    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6463  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 949      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7257     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 6725  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1758  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
print(df.isnull().sum())
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
cliente=pd.json_normalize(df['customer'])
telefono=pd.json_normalize(df['phone'])
internet=pd.json_normalize(df['internet'])
cuenta=pd.json_normalize(df['account'])

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 3219  4495-LHSSK    0.0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2843  3946-JEWRQ    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 19    0023-HGHWL    1.0  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 85    0134-XWXCE    0.0  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2765  3823-KYNQY    0.0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 3219    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2843    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 19    {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 85       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2765    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 3219  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2843  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df["Churn"] = df["Churn"].fillna(0).astype(int)

# %%
df.sample(5)
# Out:
#       customerID  Churn                                           customer  \
# 1655  2351-BKRZW      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5019  6861-XWTWQ      1  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 1211  1730-VFMWO      0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4710  6458-CYIDZ      0  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5274  7203-OYKCT      0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 1655   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5019  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1211   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4710   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5274  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 1655  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 5019  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ##Cliente

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 5462    Male              0      No         No      43
# 3771  Female              0      No         No      48
# 4438    Male              0      No         No      18
# 6854    Male              0      No         No      12
# 3114  Female              0      No        Yes      24

# %%
cliente['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cliente['Partner'] = cliente['Partner'].map({'Yes': 1, 'No': 0})
cliente['Dependents'] = cliente['Dependents'].map({'Yes': 1, 'No': 0})

# %%
cliente.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 3301    Male              0        0           0       1
# 6527  Female              1        1           0       7
# 6196  Female              0        1           0      65
# 732     Male              0        0           0      43
# 1690  Female              0        0           0       3

# %% [markdown]
# ##Telefono

# %%
telefono.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
telefono.sample(5)
# Out:
#      PhoneService     MultipleLines
# 4616          Yes               Yes
# 7173          Yes                No
# 4769          Yes               Yes
# 642           Yes               Yes
# 1830           No  No phone service

# %%
telefono['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
telefono['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
tel_trans = ['PhoneService', 'MultipleLines']
telefono[tel_trans] = telefono[tel_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No phone service': 0}))

# %%
telefono.sample(5)
# Out:
#       PhoneService  MultipleLines
# 5985             1              1
# 3441             1              0
# 125              0              0
# 4250             1              0
# 4734             1              0

# %% [markdown]
# ##Internet

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
internet.sample(5)
# Out:
#      InternetService       OnlineSecurity         OnlineBackup  \
# 5614     Fiber optic                   No                   No
# 6818     Fiber optic                   No                  Yes
# 7072     Fiber optic                  Yes                  Yes
# 3793     Fiber optic                   No                  Yes
# 1375              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5614                   No                   No                   No
# 6818                   No                   No                   No
# 7072                  Yes                  Yes                  Yes
# 3793                   No                  Yes                  Yes
# 1375  No internet service  No internet service  No internet service
#
#           StreamingMovies
# 5614                   No
# 6818                   No
# 7072                  Yes
# 3793                   No
# 1375  No internet service

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
int_trans = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
internet[int_trans] = internet[int_trans].apply(lambda x: x.map({'Yes': 1, 'No': 0, 'No internet service': 0}))

# %%
internet.sample(5)
# Out:
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 4244             DSL               0             1                 0
# 563              DSL               1             0                 0
# 2119             DSL               1             1                 1
# 4063     Fiber optic               0             0                 0
# 177              DSL               0             0                 0
#
#       TechSupport  StreamingTV  StreamingMovies
# 4244            0            1                0
# 563             1            0                0
# 2119            1            1                1
# 4063            0            1                1
# 177             1            1                1

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   int64
#  2   OnlineBackup      7267 non-null   int64
#  3   DeviceProtection  7267 non-null   int64
#  4   TechSupport       7267 non-null   int64
#  5   StreamingTV       7267 non-null   int64
#  6   StreamingMovies   7267 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 397.5+ KB

# %% [markdown]
# ##Cuenta

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
cuenta.sample(5)
# Out:
#             Contract PaperlessBilling              PaymentMethod  \
# 5022        Two year              Yes               Mailed check
# 3986        One year              Yes               Mailed check
# 1916        Two year               No               Mailed check
# 1060  Month-to-month              Yes  Bank transfer (automatic)
# 652   Month-to-month              Yes           Electronic check
#
#       Charges.Monthly Charges.Total
# 5022             52.5       1208.15
# 3986            100.3        5200.8
# 1916             71.1        213.35
# 1060            100.4       2936.25
# 652              80.5        1011.8

# %%
#Cambiar titulo de columna, reemplazando "." por "_"
cuenta.rename(columns=lambda x: x.replace('.', '_'), inplace=True)

# %%
cuenta['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
#cuenta["Charges_Total"].astype(float)
cuenta["Charges_Total"] = pd.to_numeric(cuenta["Charges_Total"], errors='coerce')

# %%
cuenta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges_Monthly   7267 non-null   float64
#  4   Charges_Total     7256 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 284.0+ KB

# %%
# Transformar la columna 'InternetService' en el DataFrame internet
internet = pd.get_dummies(internet, columns=['InternetService'], prefix='InternetService', drop_first=True)

# Transformar las columnas categóricas en el DataFrame cuenta
cuenta = pd.get_dummies(cuenta, columns=['Contract', 'PaperlessBilling', 'PaymentMethod'], prefix='', drop_first=True)

print("DataFrame internet después de la transformación:")
internet.head()
print("\nDataFrame cuenta después de la transformación:")
cuenta.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-68-2892207694.py in <cell line: 0>()
#       1 # Transformar la columna 'InternetService' en el DataFrame internet
# ----> 2 internet = pd.get_dummies(internet, columns=['InternetService'], prefix='InternetService', drop_first=True)
#       3
#       4 # Transformar las columnas categóricas en el DataFrame cuenta
#       5 cuenta = pd.get_dummies(cuenta, columns=['Contract', 'PaperlessBilling', 'PaymentMethod'], prefix='', drop_first=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
# ...

# %%
# Fusionar los DataFrames ya que normalizamos sin customerID, concatenaremos por índice.

df_merged = pd.concat([df[['customerID', 'Churn']], cliente, telefono, internet, cuenta], axis=1)

print("\nDataFrame fusionado:")
df_merged.head()
print("\nInformación del DataFrame fusionado:")
df_merged.info()
# Out:
# DataFrame fusionado:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines  OnlineSecurity  ...  \
# 0             1              0               0  ...
# 1             1              1               0  ...
# 2             1              0               0  ...
# 3             1              0               0  ...
# 4             1              0               0  ...
#
#    InternetService_Fiber optic  InternetService_No  Charges_Monthly  \
# 0                        False               False             65.6
# ...

# %%
df_merged['Cuentas_Diarias'] = df_merged['Charges_Monthly'] / 30

print("\nDataFrame fusionado con la nueva columna 'Cuentas_Diarias':")
df_merged.head()
# Out:
# DataFrame fusionado con la nueva columna 'Cuentas_Diarias':
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines  OnlineSecurity  ...  InternetService_No  \
# 0             1              0               0  ...               False
# 1             1              1               0  ...               False
# 2             1              0               0  ...               False
# 3             1              0               0  ...               False
# 4             1              0               0  ...               False
#
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
